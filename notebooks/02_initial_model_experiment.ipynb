# %% [markdown]
# # Initial Model Experiment
#
# Runs the reusable training and evaluation pipeline from the source modules.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.train import train
from src.evaluate import evaluate

# %%
model_path = train("config/config.yaml")
model_path

# %%
metrics_path = evaluate("config/config.yaml", model_path)
metrics_path
